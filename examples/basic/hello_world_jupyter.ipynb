# %%
# !pip install agents

from agents import Agent, Runner

agent = Agent(name="Assistant", instructions="You are a helpful assistant")

# Intended for Jupyter notebooks where there's an existing event loop
result = await Runner.run(agent, "Write a haiku about recursion in programming.")  # type: ignore[top-level-await]  # noqa: F704
print(result.final_output)
# Out:
# Collecting agents
#   Downloading agents-1.4.0.tar.gz (37 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (from agents) (2.20.0)
# Requirement already satisfied: gym in /usr/local/lib/python3.12/dist-packages (from agents) (0.25.2)
# Collecting ruamel.yaml (from agents)
#   Downloading ruamel_yaml-0.19.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.12/dist-packages (from gym->agents) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gym->agents) (3.1.2)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.12/dist-packages (from gym->agents) (0.1.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (26.1)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (1.80.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->agents) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow->agents) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow->agents) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow->agents) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow->agents) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->agents) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->agents) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->agents) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->agents) (2026.4.22)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow->agents) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow->agents) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow->agents) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow->agents) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow->agents) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow->agents) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow->agents) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow->agents) (0.1.2)
# Downloading ruamel_yaml-0.19.1-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 2.4 MB/s eta 0:00:00
# Building wheels for collected packages: agents
#   Building wheel for agents (setup.py) ... done
#   Created wheel for agents: filename=agents-1.4.0-py3-none-any.whl size=62714 sha256=041beac7c242d866e6b2433bbda02176fd74b96900ecdf29663f18efdc179a66
#   Stored in directory: /root/.cache/pip/wheels/e5/82/e5/2790dbbc1ad6037f1001bc436ea963e0877fff918dddc74fe2
# Successfully built agents
# Installing collected packages: ruamel.yaml, agents
# Successfully installed agents-1.4.0 ruamel.yaml-0.19.1
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_14075/664245586.py in <cell line: 0>()
#       1 get_ipython().system('pip install agents')
#       2
# ----> 3 from agents import Agent, Runner
#       4
#       5 agent = Agent(name="Assistant", instructions="You are a helpful assistant")
#
# /usr/local/lib/python3.12/dist-packages/agents/__init__.py in <module>
#      20
#      21 from . import algorithms
# ---> 22 from . import scripts
#      23 from . import tools
#
# /usr/local/lib/python3.12/dist-packages/agents/scripts/__init__.py in <module>
#      19 from __future__ import print_function
#      20
# ---> 21 from . import train
#      22 from . import utility
#      23 from . import visualize
#
# /usr/local/lib/python3.12/dist-packages/agents/scripts/train.py in <module>
#      31
#      32 from agents import tools
# ---> 33 from agents.scripts import configs
#      34 from agents.scripts import utility
#      35
#
# /usr/local/lib/python3.12/dist-packages/agents/scripts/configs.py in <module>
#      24
#      25 from agents import algorithms
# ---> 26 from agents.scripts import networks
#      27
#      28
#
# /usr/local/lib/python3.12/dist-packages/agents/scripts/networks.py in <module>
#      28 import agents
#      29
# ---> 30 tfd = tf.contrib.distributions
#      31
#      32
#
# AttributeError: module 'tensorflow' has no attribute 'contrib'
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ### Temel Pekiştirmeli Öğrenme Örneği: Stable Baselines3 ile CartPole
#
# Bu örnekte, Stable Baselines3 kütüphanesini kullanarak klasik `CartPole-v1` ortamında bir PPO (Proximal Policy Optimization) ajanını eğiteceğiz. CartPole ortamının amacı, bir arabayı sağa veya sola hareket ettirerek direğin düşmesini engellemektir.

# %%
# Gerekli kütüphaneleri yükleyin
# !pip install gymnasium stable-baselines3

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# Ortamı oluşturun
env_id = 'CartPole-v1'
vec_env = make_vec_env(env_id, n_envs=1)

print(f"Ortam oluşturuldu: {env_id}")

# %%
# PPO modelini tanımlayın ve eğitin
# MlpPolicy (Çok Katmanlı Algılayıcı Politika) kullanıyoruz çünkü gözlem ve eylem uzayları süreklidir.
model = PPO('MlpPolicy', vec_env, verbose=1)
print("Model eğitiliyor...")
model.learn(total_timesteps=10000) # 10000 zaman adımında eğitim
print("Model eğitimi tamamlandı.")

# %%
# Eğitilmiş modeli değerlendirin

obs = vec_env.reset()

num_episodes = 5
episode_rewards = []

print("Model değerlendiriliyor...")
for episode in range(num_episodes):
    done = False
    episode_reward = 0
    while not done:
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, done, info = vec_env.step(action)
        episode_reward += reward[0]
    episode_rewards.append(episode_reward)
    obs = vec_env.reset() # Her bölüm sonunda ortamı sıfırla

print(f"\n{num_episodes} bölümdeki ortalama ödül: {sum(episode_rewards) / num_episodes:.2f}")

# Ortamı kapatın
vec_env.close()
